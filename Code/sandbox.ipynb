# %%
import pandas as pd
import plotly.offline as py
import plotly.graph_objs as go
import plotly.figure_factory as ff

data = pd.read_csv('data.csv')
data.head() #The head() function is used to get the first n rows. The default value is 5 aka data.head(self,n=5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
# data = data.drop(['Unnamed: 32','id'],axis = 1) # This line has been commented out as it has already been run once and it will throw a "doesn't exixt error"
data.diagnosis.replace(to_replace = dict(M = 1, B = 0), inplace = True)

# %%
data.describe()
# Out:
#                  id   diagnosis  radius_mean  texture_mean  perimeter_mean  \
# count  5.690000e+02  569.000000   569.000000    569.000000      569.000000
# mean   3.037183e+07    0.372583    14.127292     19.289649       91.969033
# std    1.250206e+08    0.483918     3.524049      4.301036       24.298981
# min    8.670000e+03    0.000000     6.981000      9.710000       43.790000
# 25%    8.692180e+05    0.000000    11.700000     16.170000       75.170000
# 50%    9.060240e+05    0.000000    13.370000     18.840000       86.240000
# 75%    8.813129e+06    1.000000    15.780000     21.800000      104.100000
# max    9.113205e+08    1.000000    28.110000     39.280000      188.500000
#
#          area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# count   569.000000       569.000000        569.000000      569.000000
# mean    654.889104         0.096360          0.104341        0.088799
# std     351.914129         0.014064          0.052813        0.079720
# ...

# %%
data.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
def noErrors():
    print("Compilation has been completed and there are no errors in the code.")
    return True

# %%
M = data[(data['diagnosis'] != 0)]
B = data[(data['diagnosis'] == 0)]

# %%
trace = go.Bar(x = (len(M), len(B)), y = ['Malignant', 'Benign'], orientation = 'h', opacity = 0.7, marker=dict(
        color=[ 'red', 'green'],
        line=dict(color='#000000',width=1.5)))

layout = dict(title =  'Pictorial count of the data available in the dataset.')
                    
fig = dict(data = [trace], layout=layout)
py.iplot(fig)
noErrors()
# Out:
# <div>                            <div id="63cb3b36-b77c-4656-a4fe-5f645e521d7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63cb3b36-b77c-4656-a4fe-5f645e521d7d")) {                    Plotly.newPlot(                        "63cb3b36-b77c-4656-a4fe-5f645e521d7d",                        [{"marker":{"color":["red","green"],"line":{"color":"#000000","width":1.5}},"opacity":0.7,"orientation":"h","x":[212,357],"y":["Malignant","Benign"],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"
# ...

# %%
def plot_distribution(data_select, size_bin) :  
    tmp1 = M[data_select]
    tmp2 = B[data_select]
    hist_data = [tmp1, tmp2]
    
    group_labels = ['malignant', 'benign']
    colors = ['red', 'green']

    fig = ff.create_distplot(hist_data, group_labels, colors = colors, show_hist = True, bin_size = size_bin, curve_type='kde')
    
    fig['layout'].update(title = data_select)

    py.iplot(fig, filename = 'Data plot representation')

# %%
plot_distribution('radius_mean', .5)
# Out:
# <div>                            <div id="58a08810-1bef-4d22-8d7d-1b55ab12c5d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58a08810-1bef-4d22-8d7d-1b55ab12c5d0")) {                    Plotly.newPlot(                        "58a08810-1bef-4d22-8d7d-1b55ab12c5d0",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"malignant","marker":{"color":"red"},"name":"malignant","opacity":0.7,"x":[17.99,20.57,19.69,11.42,20.29,12.45,18.25,13.71,13.0,12.46,16.02,15.78,19.17,15.85,13.73,14.54,14.68,16.13,19.81,15.34,21.16,16.65,17.14,14.58,18.61,15.3,17.57,18.63,11.84,17.02,19.27,16.13,16.74,14.25,14.99,13.48,13.44,10.95,19.07,13.28,13.17,18.65,13.17,18.22,15.1,19.21,14.71,14.25,12.68,14.78,18.94,17.2,13.8,16.07,18.05,20
# ...

# %%
plot_distribution('texture_mean', .5)
# Out:
# <div>                            <div id="bce63b7e-d951-4553-81c5-71bf9dad68ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bce63b7e-d951-4553-81c5-71bf9dad68ab")) {                    Plotly.newPlot(                        "bce63b7e-d951-4553-81c5-71bf9dad68ab",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"malignant","marker":{"color":"red"},"name":"malignant","opacity":0.7,"x":[10.38,17.77,21.25,20.38,14.34,15.7,19.98,20.83,21.82,24.04,23.24,17.89,24.8,23.95,22.61,27.54,20.13,20.68,22.15,14.26,23.04,21.38,16.4,21.53,20.25,25.27,15.05,25.11,18.7,23.98,26.47,17.88,21.59,21.72,25.2,20.82,21.58,21.35,24.81,20.28,21.81,17.6,18.66,18.7,22.02,18.57,21.59,22.15,23.84,23.94,21.31,24.52,15.79,19.65,16.15,23.9
# ...

# %%
plot_distribution('perimeter_mean', 5)
# Out:
# <div>                            <div id="2715cd6b-f819-44ea-a331-9633e0b3600b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2715cd6b-f819-44ea-a331-9633e0b3600b")) {                    Plotly.newPlot(                        "2715cd6b-f819-44ea-a331-9633e0b3600b",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"malignant","marker":{"color":"red"},"name":"malignant","opacity":0.7,"x":[122.8,132.9,130.0,77.58,135.1,82.57,119.6,90.2,87.5,83.97,102.7,103.6,132.4,103.7,93.6,96.73,94.74,108.1,130.0,102.5,137.2,110.0,116.0,97.41,122.1,102.4,115.0,124.8,77.93,112.8,127.9,107.0,110.1,93.63,95.54,88.4,86.18,71.9,128.3,87.32,85.42,123.7,85.98,120.3,97.26,125.5,95.55,96.42,82.69,97.4,123.6,114.2,90.43,104.1,120.2,143
# ...

# %%
plot_distribution('area_mean', 10)
# Out:
# <div>                            <div id="618700ed-9d0c-43b2-89c9-2cea41387d4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("618700ed-9d0c-43b2-89c9-2cea41387d4b")) {                    Plotly.newPlot(                        "618700ed-9d0c-43b2-89c9-2cea41387d4b",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"malignant","marker":{"color":"red"},"name":"malignant","opacity":0.7,"x":[1001.0,1326.0,1203.0,386.1,1297.0,477.1,1040.0,577.9,519.8,475.9,797.8,781.0,1123.0,782.7,578.3,658.8,684.5,798.8,1260.0,704.4,1404.0,904.6,912.7,644.8,1094.0,732.4,955.1,1088.0,440.6,899.3,1162.0,807.2,869.5,633.0,698.8,559.2,563.0,371.1,1104.0,545.2,531.5,1076.0,534.6,1033.0,712.8,1152.0,656.9,645.7,499.0,668.3,1130.0,929.4
# ...

# %%
plot_distribution('radius_worst', .5)
# Out:
# <div>                            <div id="a767f559-2122-473d-9e59-9cdc8544612f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a767f559-2122-473d-9e59-9cdc8544612f")) {                    Plotly.newPlot(                        "a767f559-2122-473d-9e59-9cdc8544612f",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"malignant","marker":{"color":"red"},"name":"malignant","opacity":0.7,"x":[25.38,24.99,23.57,14.91,22.54,15.47,22.88,17.06,15.49,15.09,19.19,20.42,20.96,16.84,15.03,17.46,19.07,20.96,27.32,18.07,29.17,26.46,22.25,17.62,21.31,20.27,20.01,23.15,16.82,20.88,24.15,20.21,20.01,15.89,14.99,15.53,15.93,12.84,24.09,17.38,16.23,22.82,15.67,20.6,18.1,26.14,17.87,17.67,17.09,17.31,24.86,23.32,16.57,19.77,22.39
# ...

# %%
plot_distribution('texture_worst', .5)
# Out:
# <div>                            <div id="9e93ffa5-5382-4d6c-9ea5-5d1bae4eb95c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e93ffa5-5382-4d6c-9ea5-5d1bae4eb95c")) {                    Plotly.newPlot(                        "9e93ffa5-5382-4d6c-9ea5-5d1bae4eb95c",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"malignant","marker":{"color":"red"},"name":"malignant","opacity":0.7,"x":[17.33,23.41,25.53,26.5,16.67,23.75,27.66,28.14,30.73,40.68,33.88,27.28,29.94,27.66,32.01,37.13,30.88,31.48,30.88,19.08,35.59,31.56,21.4,33.21,27.26,36.71,19.52,34.01,28.12,32.09,30.9,27.26,29.02,30.36,25.2,26.02,30.25,35.34,33.17,28.0,29.89,21.32,27.95,24.13,31.69,28.14,30.7,29.51,33.47,33.39,26.58,33.82,20.86,24.56,18.91,31.
# ...

# %%
plot_distribution('perimeter_worst', 5)
# Out:
# <div>                            <div id="3c69958e-4921-4b9d-8e9c-71cbbc82090c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c69958e-4921-4b9d-8e9c-71cbbc82090c")) {                    Plotly.newPlot(                        "3c69958e-4921-4b9d-8e9c-71cbbc82090c",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"malignant","marker":{"color":"red"},"name":"malignant","opacity":0.7,"x":[184.6,158.8,152.5,98.87,152.2,103.4,153.2,110.6,106.2,97.65,123.8,136.5,151.7,112.0,108.8,124.1,123.4,136.8,186.8,125.1,188.0,177.0,152.4,122.4,139.9,149.3,134.9,160.5,119.4,136.1,161.4,132.7,133.5,116.2,95.54,107.3,102.5,87.22,177.4,113.1,105.5,150.6,102.8,135.1,117.7,170.1,115.7,119.1,111.8,114.6,165.9,151.6,110.3,128.8,150
# ...

# %%
plot_distribution('area_worst', 10)
# Out:
# <div>                            <div id="b8015c0f-d505-4fae-9379-ec6f1cfbdc34" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8015c0f-d505-4fae-9379-ec6f1cfbdc34")) {                    Plotly.newPlot(                        "b8015c0f-d505-4fae-9379-ec6f1cfbdc34",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"malignant","marker":{"color":"red"},"name":"malignant","opacity":0.7,"x":[2019.0,1956.0,1709.0,567.7,1575.0,741.6,1606.0,897.0,739.3,711.4,1150.0,1299.0,1332.0,876.5,697.7,943.2,1138.0,1315.0,2398.0,980.9,2615.0,2215.0,1461.0,896.9,1403.0,1269.0,1227.0,1670.0,888.7,1344.0,1813.0,1261.0,1229.0,799.6,698.8,740.4,787.9,514.0,1651.0,907.2,740.7,1567.0,759.4,1321.0,1030.0,2145.0,985.5,959.5,888.3,925.1,
# ...
